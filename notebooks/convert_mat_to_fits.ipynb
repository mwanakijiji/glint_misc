# %%
import scipy.io
import h5py
import glob
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# %%
stem = '/Volumes/One Touch/glint_old_data/alfBoo_1/'

# %%
file_list = glob.glob(stem + '*.mat')

# %%
# Open the HDF5 file
for file_name in file_list:
    with h5py.File(file_name, 'r') as file:

        # Check if 'imagedata' exists in the file
        if 'imagedata' in file:
            imagedata = file['imagedata']
            imagedata_array = imagedata[:]

        else:
            print("Dataset 'imagedata' not found in the file.")

        # Write out imagedata_array as a FITS file
        file_name_write = file_name.split('.')[0] + '.fits'
        hdu = fits.PrimaryHDU(imagedata_array.astype(imagedata_array.dtype))
        hdu.writeto(file_name_write, overwrite=True)
        print("FITS file saved as:", file_name_write)
# Out:
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232933461.fits
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232930581.fits
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232933397.fits
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232930658.fits
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232933529.fits
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232930715.fits
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232933594.fits
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232930783.fits
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232933932.fits
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232930848.fits
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232933997.fits
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232930917.fits
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232934067.fits
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232930983.fits
# FITS file saved as: /Volumes/One Touch/glint_old_data/alfBoo_1/dark_20210429T232934132.fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 8
#       6 if 'imagedata' in file:
#       7     imagedata = file['imagedata']
# ----> 8     imagedata_array = imagedata[:]
#      10 else:
#      11     print("Dataset 'imagedata' not found in the file.")
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/anaconda3/envs/glint_env/lib/python3.10/site-packages/h5py/_hl/dataset.py:758, in Dataset.__getitem__(self, args, new_dtype)
#     756 if self._fast_read_ok and (new_dtype is None):
#     757     try:
# --> 758         return self._fast_reader.read(args)
#     759     except TypeError:
#     760         pass  # Fall back to Python read pathway below
#
# KeyboardInterrupt:

# %%
imagedata_array.dtype
# Out:
# dtype('uint16')

# %%
plt.imshow(imagedata_array[0,:,:], norm=LogNorm())
plt.show()
plt.show()

# %%
np.shape(mat)
# Out:
# (1,)

# %%
type(imagedata_array[0,0,0])
# Out:
# numpy.uint16
