# %%
import pandas as pd

# %%
stem = '/Users/bandari/Documents/git.repos/glint_misc/notebooks/'

# %%
df = pd.read_csv(stem + 'data/full_HPIC.txt', delimiter='|')

# %%
list(df.keys())
# Out:
# ['star_name',
#  'ra',
#  'dec',
#  'ra_J2016',
#  'dec_J2016',
#  'tic_id',
#  'gaia_dr2_id',
#  'gaia_dr3_id',
#  'hip_name',
#  'tm_name',
#  'tyc_name',
#  'wds_designation',
#  'simbad_name',
#  'source_list_fl',
#  'sy_pmra',
#  'sy_pmraerr',
#  'sy_pmdec',
#  'sy_pmdecerr',
#  'sy_pmsrc',
#  'sy_pm_reflink',
#  'sy_ujmag',
#  'sy_ujmagerr',
#  'sy_ujmagsrc',
#  'sy_ujmag_reflink',
#  'sy_bmag',
#  'sy_bmagerr',
#  'sy_bmagsrc',
#  'sy_bmag_reflink',
#  'sy_vmag',
#  'sy_vmagerr',
#  'sy_vmagsrc',
#  'sy_vmag_reflink',
#  'sy_rcmag',
#  'sy_rcmagerr',
#  'sy_rcmagsrc',
#  'sy_rcmag_reflink',
#  'sy_icmag',
#  'sy_icmagerr',
#  'sy_icmagsrc',
#  'sy_icmag_reflink',
#  'sy_jmag',
#  'sy_jmagerr',
#  'sy_jmagsrc',
#  'sy_jmag_reflink',
#  'sy_hmag',
#  'sy_hmagerr',
#  'sy_hmagsrc',
#  'sy_hmag_reflink',
#  'sy_kmag',
#  'sy_kmagmerr',
#  'sy_kmagsrc',
#  'sy_kmag_reflink',
#  'sy_tmag',
#  'sy_tmagerr',
#  'sy_gaiamag',
#  'sy_gaiamagerr',
#  'sy_gaiamagsrc',
# ...

# %%
df['st_spectype'] = df['st_spectype'].astype(str)
sorted_list = sorted(df['st_spectype'])

# Count the number of instances where string elements begin with 'B'
count_o = sum(1 for item in sorted_list if item.startswith('O'))

# Count the number of instances where string elements begin with 'B'
count_b = sum(1 for item in sorted_list if item.startswith('B'))

# Count the number of instances where string elements begin with 'A'
count_a = sum(1 for item in sorted_list if item.startswith('A'))


# Count the number of instances where string elements begin with 'F'
count_f = sum(1 for item in sorted_list if item.startswith('F'))

# Count the number of instances where string elements begin with 'G'
count_g = sum(1 for item in sorted_list if item.startswith('G'))

# Count the number of instances where string elements begin with 'K'
count_k = sum(1 for item in sorted_list if item.startswith('K'))

# Count the number of instances where string elements begin with 'M'
count_m = sum(1 for item in sorted_list if item.startswith('M'))

# Count the number of instances where string elements begin with 'L'
count_l = sum(1 for item in sorted_list if item.startswith('L'))

# Count the number of instances where string elements begin with 'T'
count_t = sum(1 for item in sorted_list if item.startswith('T'))

# Count the number of instances where string elements begin with 'Y'
count_y = sum(1 for item in sorted_list if item.startswith('Y'))

# Count the number of instances where string elements begin with any other letter
count_other = len(sorted_list) - count_o - count_a - count_b - count_g - count_f - count_k - count_m - count_l - count_t - count_y

print(f"Number of instances starting with 'O': {count_o}")
print(f"Number of instances starting with 'B': {count_b}")
print(f"Number of instances starting with 'A': {count_a}")
print(f"Number of instances starting with 'F': {count_f}")
print(f"Number of instances starting with 'G': {count_g}")
print(f"Number of instances starting with 'K': {count_k}")
print(f"Number of instances starting with 'M': {count_m}")
print(f"Number of instances starting with 'L': {count_l}")
print(f"Number of instances starting with 'T': {count_t}")
print(f"Number of instances starting with 'Y': {count_y}")
print(f"Number of instances starting with other letters: {count_other}")
# Out:
# Number of instances starting with 'O': 2
# Number of instances starting with 'B': 23
# Number of instances starting with 'A': 207
# Number of instances starting with 'F': 1198
# Number of instances starting with 'G': 2079
# Number of instances starting with 'K': 3757
# Number of instances starting with 'M': 2857
# Number of instances starting with 'L': 0
# Number of instances starting with 'T': 0
# Number of instances starting with 'Y': 0
# Number of instances starting with other letters: 2821
